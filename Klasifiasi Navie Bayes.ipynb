# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import folium
from folium.plugins import MarkerCluster
from geopy.geocoders import Nominatim
import time

# %%
# Load dataset
df = pd.read_excel('dataset_banjir_jkt.xlsx')
df
# Out:
#      Range Tahun      Kecamatan  Rata - Rata Ketinggian Air (cm)  \
# 0           2023  Tanjung Priok                               75
# 1           2021         Cakung                               35
# 2           2022      Kalideres                              145
# 3           2023      Kemayoran                               50
# 4           2024         Cakung                               75
# ..           ...            ...                              ...
# 205         2021          Tebet                              170
# 206         2022          Tebet                               73
# 207         2023          Tebet                              123
# 208         2024          Tebet                               94
# 209         2024      Kembangan                              129
#
#     Intensitas Curah Hujan (mm/jam)  Debit Air (m3/s)  Lamanya Hujan (Jam)  \
# 0                              0.56              1973                    1
# 1                             96.39              2956                    1
# 2                              6.68              2165                    2
# 3                              7.13              3681                    1
# 4                             87.61              2287                    4
# ..                              ...               ...                  ...
# 205                           56.06              3563                    3
# 206                           71.31              4619                    1
# 207                           87.52              4665                    3
# 208                           20.11              4766                    1
# 209                           89.43              3365                    3
#
#      Target (Banjir/Tidak)  Perbaikan Jalan (Ada/Tidak)
# 0                        1                            1
# 1                        0                            1
# 2                        1                            0
# 3                        1                            0
# 4                        1                            0
# ..                     ...                          ...
# 205                      0                            1
# 206                      0                            0
# 207                      1                            0
# 208                      0                            0
# 209                      0                            1
#
# [210 rows x 8 columns]

# %%
# Tampilkan info dataset untuk memeriksa kolom dan tipe data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 8 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Range Tahun                      210 non-null    int64
#  1   Kecamatan                        210 non-null    object
#  2   Rata - Rata Ketinggian Air (cm)  210 non-null    int64
#  3   Intensitas Curah Hujan (mm/jam)  210 non-null    object
#  4   Debit Air (m3/s)                 210 non-null    int64
#  5   Lamanya Hujan (Jam)              210 non-null    int64
#  6   Target (Banjir/Tidak)            210 non-null    int64
#  7   Perbaikan Jalan (Ada/Tidak)      210 non-null    int64
# dtypes: int64(6), object(2)
# memory usage: 13.2+ KB

# %%
# Tampilkan statistik deskriptif untuk memeriksa data
df.describe()
# Out:
#        Range Tahun  Rata - Rata Ketinggian Air (cm)  Debit Air (m3/s)  \
# count   210.000000                       210.000000        210.000000
# mean   2022.000000                        93.142857       2451.571429
# std       1.417593                        36.315979       1428.499647
# min    2020.000000                        25.000000          2.000000
# 25%    2021.000000                        66.000000       1369.500000
# 50%    2022.000000                        87.000000       2443.000000
# 75%    2023.000000                       118.500000       3664.500000
# max    2024.000000                       170.000000       4962.000000
#
#        Lamanya Hujan (Jam)  Target (Banjir/Tidak)  Perbaikan Jalan (Ada/Tidak)
# count           210.000000             210.000000                   210.000000
# mean              2.428571               0.509524                     0.509524
# std               1.131178               0.501104                     0.501104
# min               1.000000               0.000000                     0.000000
# 25%               2.000000               0.000000                     0.000000
# 50%               2.000000               1.000000                     1.000000
# 75%               3.000000               1.000000                     1.000000
# max               5.000000               1.000000                     1.000000

# %%
# --- Data Cleaning ---
# Menghapus kolom yang tidak diperlukan (jika ada)
df.dropna(axis=1, how='all', inplace=True)

# %%
# Menghapus baris dengan nilai NaN pada kolom yang relevan
df = df.dropna()

# %%
# Menyaring kolom yang relevan untuk model
df['Target (Banjir/Tidak)'] = df['Target (Banjir/Tidak)'].astype(int)  # Pastikan kolom target berupa integer

# %%
# Periksa apakah ada nilai NaN setelah konversi
df.isna().sum()  # Mengecek apakah masih ada nilai NaN
# Out:
# Range Tahun                        0
# Kecamatan                          0
# Rata - Rata Ketinggian Air (cm)    0
# Intensitas Curah Hujan (mm/jam)    0
# Debit Air (m3/s)                   0
# Lamanya Hujan (Jam)                0
# Target (Banjir/Tidak)              0
# Perbaikan Jalan (Ada/Tidak)        0
# dtype: int64

# %%
# --- Split Data ---
# Menyiapkan fitur (X) dan target (y)
X = df[['Kecamatan', 'Range Tahun', 'Perbaikan Jalan (Ada/Tidak)']]  # Ganti sesuai dengan kolom yang relevan
y = df['Target (Banjir/Tidak)']

# %%
# Encoding fitur kategorikal jika perlu (misalnya kecamatan dan range tahun)
X = pd.get_dummies(X, columns=['Kecamatan', 'Range Tahun'], drop_first=True)

# %%
# Split data menjadi data latih dan data uji
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Standardisasi fitur numerik
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# --- Model Naive Bayes ---
# Membuat dan melatih model Naive Bayes
model = GaussianNB()
model.fit(X_train_scaled, y_train)
# Out:
# GaussianNB()

# %%
# Prediksi hasil
y_pred = model.predict(X_test_scaled)

# %%
# Evaluasi Model
conf_matrix = confusion_matrix(y_test, y_pred)
acc_score = accuracy_score(y_test, y_pred)
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n", classification_report(y_test, y_pred))
print(f"Accuracy: {acc_score * 100:.2f}%")
# Out:
# Confusion Matrix:
#  [[10 18]
#  [ 4 31]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.71      0.36      0.48        28
#            1       0.63      0.89      0.74        35
#
#     accuracy                           0.65        63
#    macro avg       0.67      0.62      0.61        63
# weighted avg       0.67      0.65      0.62        63
#
# Accuracy: 65.08%

# %%
# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# Visualisasi Confusion Matrix
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Tidak Banjir', 'Banjir'], yticklabels=['Tidak Banjir', 'Banjir'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
# Fungsi untuk membuat Pie Chart berdasarkan tahun yang dipilih
def create_pie_chart_by_year(year):
    df_filtered = df[df["Range Tahun"] == year]
    pie_data = df_filtered["Target (Banjir/Tidak)"].value_counts()

    labels = ["Tidak Banjir", "Banjir"]
    colors = ['skyblue', 'orange']

    # Membuat Pie Chart
    plt.figure(figsize=(6, 6))
    plt.pie(pie_data, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140, textprops={'fontsize': 14})
    plt.title(f"Perbandingan Banjir vs Tidak Banjir pada Tahun {year}")
    plt.show()

# %%
# Contoh penggunaan untuk menampilkan Pie Chart untuk tahun 2020 - 2024
tahun_pilihan = 2020 # Ganti dengan tahun yang diinginkan
create_pie_chart_by_year(tahun_pilihan)

# %%
# Contoh penggunaan untuk menampilkan Pie Chart untuk tahun 2020 - 2024
tahun_pilihan = 2021 # Ganti dengan tahun yang diinginkan
create_pie_chart_by_year(tahun_pilihan)

# %%
# Contoh penggunaan untuk menampilkan Pie Chart untuk tahun 2020 - 2024
tahun_pilihan = 2022 # Ganti dengan tahun yang diinginkan
create_pie_chart_by_year(tahun_pilihan)

# %%
# Contoh penggunaan untuk menampilkan Pie Chart untuk tahun 2020 - 2024
tahun_pilihan = 2023 # Ganti dengan tahun yang diinginkan
create_pie_chart_by_year(tahun_pilihan)

# %%
# Contoh penggunaan untuk menampilkan Pie Chart untuk tahun 2020 - 2024
tahun_pilihan = 2024 # Ganti dengan tahun yang diinginkan
create_pie_chart_by_year(tahun_pilihan)

# %%
# Inisialisasi geolocator untuk mendapatkan koordinat
geolocator = Nominatim(user_agent="mapping_banjir_jkt", timeout=5)  # Timeout 5 detik
coordinates = {}

# %%
# Fungsi untuk membuat peta berdasarkan tahun yang dipilih
def create_map_by_year(year):
    df_filtered = df[df["Range Tahun"] == year]
    m = folium.Map(location=[-6.2, 106.85], zoom_start=11)

    # Tambahkan MarkerCluster untuk mengelompokkan marker
    marker_cluster = MarkerCluster().add_to(m)

    # Loop untuk menambahkan marker ke peta
    for _, row in df_filtered.iterrows():
        kecamatan = row["Kecamatan"]
        status_banjir = row["Target (Banjir/Tidak)"]
        perbaikan_jalan = row["Perbaikan Jalan (Ada/Tidak)"]

        # Periksa apakah koordinat kecamatan sudah ada dalam dictionary
        if kecamatan not in coordinates:
            try:
                location = geolocator.geocode(f"{kecamatan}, Jakarta, Indonesia")
                if location:
                    coordinates[kecamatan] = (location.latitude, location.longitude)
                else:
                    print(f"Koordinat tidak ditemukan: {kecamatan}")
                    continue
            except Exception as e:
                print(f"Error saat mendapatkan koordinat {kecamatan}: {e}")
                time.sleep(1)
                continue

        # Ambil koordinat kecamatan
        lokasi = coordinates.get(kecamatan)
        if lokasi:
            # Tentukan warna marker berdasarkan status banjir
            warna = "red" if status_banjir == 1 else "green"

            # Informasi pop-up
            popup_info = (
                f"<b>Kecamatan:</b> {kecamatan}<br>"
                f"<b>Status Banjir:</b> {'Banjir' if status_banjir == 1 else 'Tidak Banjir'}<br>"
                f"<b>Perbaikan Jalan:</b> {'Ada' if perbaikan_jalan == 1 else 'Tidak'}"
            )

            # Tambahkan marker ke peta
            folium.Marker(
                location=lokasi,
                popup=popup_info,
                icon=folium.Icon(color=warna)
            ).add_to(marker_cluster)

    # Mengembalikan peta yang telah dibuat
    return m

# %%
# Contoh penggunaan untuk menampilkan peta untuk tahun 2020-2024
map_result = create_map_by_year(2020)

# Menampilkan peta
map_result
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_be9a2b1773eb2fe32844fbeb6469e60c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_be9a2b1773eb2fe32844fbeb6469e60c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_be9a2b1773eb2fe32844fbeb6469e60c = L.map(
#                 &quot;map_be9a2b1773eb2fe32844fbeb6469e60c&quot;,
#                 {
#                     center: [-6.2, 106.85],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bd507645a9f1cd63e54a8039a6a7547a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bd507645a9f1cd63e54a8039a6a7547a.addTo(map_be9a2b1773eb2fe32844fbeb6469e60c);
#
#
#             var marker_cluster_269bb9bbb56b8e24acbc4fbb114454f8 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_1d76cfb234ccc58c12f76da1d2e8788e = L.marker(
#                 [-6.1617033, 106.8414012],
#                 {
# }
#             ).addTo(marker_cluster_269bb9bbb56b8e24acbc4fbb114454f8);
#
#
#             var icon_d7629fa761a9ee2ea30a00e6d8111cd9 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_1d76cfb234ccc58c12f76da1d2e8788e.setIcon(icon_d7629fa761a9ee2ea30a00e6d8111cd9);
#
#
#         var popup_b41ccafe666da849a4200a0cfe8900c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9048c9409617b1b263a656af396ab8d8 = $(`&lt;div id=&quot;html_9048c9409617b1b263a656af396ab8d8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Kecamatan:&lt;/b&gt; Kemayoran&lt;br&gt;&lt;b&gt;Status Banjir:&lt;/b&gt; Banjir&lt;br&gt;&lt;b&gt;Perbaikan Jalan:&lt;/b&gt; Tidak&lt;/div&gt;`)[0];
#                 popup_b41ccafe666da849a4200a0cfe8900c0.setContent(html_9048c9409617b1b263a656af396ab8d8);
#
#
#
#         marker_1d76cfb234ccc58c12f76da1d2e8788e.bindPopup(popup_b41ccafe666da849a4200a0cfe8900c0)
#         ;
#
#
#
#
#             var marker_bfb9e22e44078780498621e9e219bc92 = L.marker(
#                 [-6.1641878, 106.78831657883393],
#                 {
# }
#             ).addTo(marker_cluster_269bb9bbb56b8e24acbc4fbb114454f8);
#
#
#             var icon_fb3cd4803b7fb453e09b0f18a31fea76 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_bfb9e22e44078780498621e9e219bc92.setIcon(icon_fb3cd4803b7fb453e09b0f18a31fea76);
#
#
#         var popup_65174c0a1b471d030ab1082c5581fc1a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d0eb626ee7706210e132e6286be991f6 = $(`&lt;div id=&quot;html_d0eb626ee7706210e132e6286be991f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Kecamatan:&lt;/b&gt; Grogol Petamburan&lt;br&gt;&lt;b&gt;Status Banjir:&lt;/b&gt; Tidak Banjir&lt;br&gt;&lt;b&gt;Perbaikan Jalan:&lt;/b&gt; Tidak&lt;/div&gt;`)[0];
#                 popup_65174c0a1b471d030ab1082c5581fc1a.setContent(html_d0eb626ee7706210e132e6286be991f6);
#
#
#
#         marker_bfb9e22e44078780498621e9e219bc92.bindPopup(popup_65174c0a1b471d030ab1082c5581fc1a)
#         ;
#
#
#
#
#             var marker_2300452bf7ba5048c49c43e070401a0b = L.marker(
#                 [-6.3296346, 106.87660392506864],
#                 {
# }
#             ).addTo(marker_cluster_269bb9bbb56b8e24acbc4fbb114454f8);
#
#
#             var icon_173e98494dc9be640f3319996993dc9d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_2300452bf7ba5048c49c43e070401a0b.setIcon(icon_173e98494dc9be640f3319996993dc9d);
#
#
#         var popup_28e01053fe54db8baba870d5ac

# %%
# Contoh penggunaan untuk menampilkan peta untuk tahun 2020-2024
map_result = create_map_by_year(2021)

# Menampilkan peta
map_result
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d89efb55ddc7d9f3444bf2da8dc2130f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d89efb55ddc7d9f3444bf2da8dc2130f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d89efb55ddc7d9f3444bf2da8dc2130f = L.map(
#                 &quot;map_d89efb55ddc7d9f3444bf2da8dc2130f&quot;,
#                 {
#                     center: [-6.2, 106.85],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6a7873d6f0323aa6853ed685365dafc5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6a7873d6f0323aa6853ed685365dafc5.addTo(map_d89efb55ddc7d9f3444bf2da8dc2130f);
#
#
#             var marker_cluster_078ac3af5a71fc24b5d98f1f8641c564 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_fb08159bc511e513fa296acc8e3addec = L.marker(
#                 [-6.219081, 106.9524791],
#                 {
# }
#             ).addTo(marker_cluster_078ac3af5a71fc24b5d98f1f8641c564);
#
#
#             var icon_370e7e2d36cc9bc1f38f6773b8567113 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_fb08159bc511e513fa296acc8e3addec.setIcon(icon_370e7e2d36cc9bc1f38f6773b8567113);
#
#
#         var popup_f956e5ea7588c3be262a216f157f76d0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_56182a9ee0171ee5357fb7597864a277 = $(`&lt;div id=&quot;html_56182a9ee0171ee5357fb7597864a277&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Kecamatan:&lt;/b&gt; Cakung&lt;br&gt;&lt;b&gt;Status Banjir:&lt;/b&gt; Tidak Banjir&lt;br&gt;&lt;b&gt;Perbaikan Jalan:&lt;/b&gt; Ada&lt;/div&gt;`)[0];
#                 popup_f956e5ea7588c3be262a216f157f76d0.setContent(html_56182a9ee0171ee5357fb7597864a277);
#
#
#
#         marker_fb08159bc511e513fa296acc8e3addec.bindPopup(popup_f956e5ea7588c3be262a216f157f76d0)
#         ;
#
#
#
#
#             var marker_f1b7cfec91ddd24b06a376162521488c = L.marker(
#                 [-6.181214499999999, 106.86854766095992],
#                 {
# }
#             ).addTo(marker_cluster_078ac3af5a71fc24b5d98f1f8641c564);
#
#
#             var icon_1ebcd3e44156dc95c8e999ac6119bac2 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_f1b7cfec91ddd24b06a376162521488c.setIcon(icon_1ebcd3e44156dc95c8e999ac6119bac2);
#
#
#         var popup_d75b4d3b69660327457c031e31efc0a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a92d10682d3daf52024d311a52ca8285 = $(`&lt;div id=&quot;html_a92d10682d3daf52024d311a52ca8285&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Kecamatan:&lt;/b&gt; Cempaka Putih&lt;br&gt;&lt;b&gt;Status Banjir:&lt;/b&gt; Tidak Banjir&lt;br&gt;&lt;b&gt;Perbaikan Jalan:&lt;/b&gt; Ada&lt;/div&gt;`)[0];
#                 popup_d75b4d3b69660327457c031e31efc0a5.setContent(html_a92d10682d3daf52024d311a52ca8285);
#
#
#
#         marker_f1b7cfec91ddd24b06a376162521488c.bindPopup(popup_d75b4d3b69660327457c031e31efc0a5)
#         ;
#
#
#
#
#             var marker_3879b547bb5bcdc3a3b4f08427b4da9b = L.marker(
#                 [-6.1528985, 106.74471823726267],
#                 {
# }
#             ).addTo(marker_cluster_078ac3af5a71fc24b5d98f1f8641c564);
#
#
#             var icon_64db0ccf311a682e18b72e56139a681a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_3879b547bb5bcdc3a3b4f08427b4da9b.setIcon(icon_64db0ccf311a682e18b72e56139a681a);
#
#
#         var popup_fe292fd594b93e39830b4187

# %%
# Contoh penggunaan untuk menampilkan peta untuk tahun 2020-2024
map_result = create_map_by_year(2022)

# Menampilkan peta
map_result
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_156c62cdc3c990627d6844bef487a773 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_156c62cdc3c990627d6844bef487a773&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_156c62cdc3c990627d6844bef487a773 = L.map(
#                 &quot;map_156c62cdc3c990627d6844bef487a773&quot;,
#                 {
#                     center: [-6.2, 106.85],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_57ecbf8bb49fe783ad28fb4c23e7f4cf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_57ecbf8bb49fe783ad28fb4c23e7f4cf.addTo(map_156c62cdc3c990627d6844bef487a773);
#
#
#             var marker_cluster_cbc69ec1c29b6845cca164a5897abd57 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_44832a6421fdc6d873ff98b444e0f379 = L.marker(
#                 [-6.13700575, 106.70159379305983],
#                 {
# }
#             ).addTo(marker_cluster_cbc69ec1c29b6845cca164a5897abd57);
#
#
#             var icon_0c46770a867cdd2bb5e142f799631356 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_44832a6421fdc6d873ff98b444e0f379.setIcon(icon_0c46770a867cdd2bb5e142f799631356);
#
#
#         var popup_dded2bd214ac1d21422ed028b0ccc33d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_924dde6afb8a4eb8fee1f8daf5c49d70 = $(`&lt;div id=&quot;html_924dde6afb8a4eb8fee1f8daf5c49d70&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Kecamatan:&lt;/b&gt; Kalideres&lt;br&gt;&lt;b&gt;Status Banjir:&lt;/b&gt; Banjir&lt;br&gt;&lt;b&gt;Perbaikan Jalan:&lt;/b&gt; Tidak&lt;/div&gt;`)[0];
#                 popup_dded2bd214ac1d21422ed028b0ccc33d.setContent(html_924dde6afb8a4eb8fee1f8daf5c49d70);
#
#
#
#         marker_44832a6421fdc6d873ff98b444e0f379.bindPopup(popup_dded2bd214ac1d21422ed028b0ccc33d)
#         ;
#
#
#
#
#             var marker_175768730121f774d047c3356df7a1c0 = L.marker(
#                 [-6.1466142, 106.80104559691304],
#                 {
# }
#             ).addTo(marker_cluster_cbc69ec1c29b6845cca164a5897abd57);
#
#
#             var icon_ab7c9d0b3c62c13e8166855f9b33228b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_175768730121f774d047c3356df7a1c0.setIcon(icon_ab7c9d0b3c62c13e8166855f9b33228b);
#
#
#         var popup_f61dd9240b98af412e74660fb2fe9aed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6590ce40b4720e243f1e9870b922be46 = $(`&lt;div id=&quot;html_6590ce40b4720e243f1e9870b922be46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Kecamatan:&lt;/b&gt; Tambora&lt;br&gt;&lt;b&gt;Status Banjir:&lt;/b&gt; Tidak Banjir&lt;br&gt;&lt;b&gt;Perbaikan Jalan:&lt;/b&gt; Ada&lt;/div&gt;`)[0];
#                 popup_f61dd9240b98af412e74660fb2fe9aed.setContent(html_6590ce40b4720e243f1e9870b922be46);
#
#
#
#         marker_175768730121f774d047c3356df7a1c0.bindPopup(popup_f61dd9240b98af412e74660fb2fe9aed)
#         ;
#
#
#
#
#             var marker_c294218531b4d4e2e17fc3f68c466ff2 = L.marker(
#                 [-6.1617033, 106.8414012],
#                 {
# }
#             ).addTo(marker_cluster_cbc69ec1c29b6845cca164a5897abd57);
#
#
#             var icon_694198e2355ba7ce2ab19a49476020da = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_c294218531b4d4e2e17fc3f68c466ff2.setIcon(icon_694198e2355ba7ce2ab19a49476020da);
#
#
#         var popup_2b63956c5875c7fc223372951dd351af = L.

# %%
# Contoh penggunaan untuk menampilkan peta untuk tahun 2020-2024
map_result = create_map_by_year(2023)

# Menampilkan peta
map_result
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e1f7fcca199649108eb2a8471f92528e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e1f7fcca199649108eb2a8471f92528e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e1f7fcca199649108eb2a8471f92528e = L.map(
#                 &quot;map_e1f7fcca199649108eb2a8471f92528e&quot;,
#                 {
#                     center: [-6.2, 106.85],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7c0607d6a280d87d149cda9ca6826fe8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7c0607d6a280d87d149cda9ca6826fe8.addTo(map_e1f7fcca199649108eb2a8471f92528e);
#
#
#             var marker_cluster_554eb163909c36c11ce9c63a8cc3b6c8 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_f671e3f56e0f6f754c603121f140f6c1 = L.marker(
#                 [-6.12885785, 106.87079323031739],
#                 {
# }
#             ).addTo(marker_cluster_554eb163909c36c11ce9c63a8cc3b6c8);
#
#
#             var icon_9985696e138065c35c82c8ae1ca665f1 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_f671e3f56e0f6f754c603121f140f6c1.setIcon(icon_9985696e138065c35c82c8ae1ca665f1);
#
#
#         var popup_fb731154863d36bddd2b555864e84b45 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea9b90a60fe11971e45131230c0cfc76 = $(`&lt;div id=&quot;html_ea9b90a60fe11971e45131230c0cfc76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Kecamatan:&lt;/b&gt; Tanjung Priok&lt;br&gt;&lt;b&gt;Status Banjir:&lt;/b&gt; Banjir&lt;br&gt;&lt;b&gt;Perbaikan Jalan:&lt;/b&gt; Ada&lt;/div&gt;`)[0];
#                 popup_fb731154863d36bddd2b555864e84b45.setContent(html_ea9b90a60fe11971e45131230c0cfc76);
#
#
#
#         marker_f671e3f56e0f6f754c603121f140f6c1.bindPopup(popup_fb731154863d36bddd2b555864e84b45)
#         ;
#
#
#
#
#             var marker_1ef267778ac28de23dce03c911a09656 = L.marker(
#                 [-6.1617033, 106.8414012],
#                 {
# }
#             ).addTo(marker_cluster_554eb163909c36c11ce9c63a8cc3b6c8);
#
#
#             var icon_02eede5928c56b9bb1178f4b23f5bee1 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_1ef267778ac28de23dce03c911a09656.setIcon(icon_02eede5928c56b9bb1178f4b23f5bee1);
#
#
#         var popup_1f5abf022d1a01147a0a19bc44579c79 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_595c38542493494583022a786f1fe13f = $(`&lt;div id=&quot;html_595c38542493494583022a786f1fe13f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Kecamatan:&lt;/b&gt; Kemayoran&lt;br&gt;&lt;b&gt;Status Banjir:&lt;/b&gt; Banjir&lt;br&gt;&lt;b&gt;Perbaikan Jalan:&lt;/b&gt; Tidak&lt;/div&gt;`)[0];
#                 popup_1f5abf022d1a01147a0a19bc44579c79.setContent(html_595c38542493494583022a786f1fe13f);
#
#
#
#         marker_1ef267778ac28de23dce03c911a09656.bindPopup(popup_1f5abf022d1a01147a0a19bc44579c79)
#         ;
#
#
#
#
#             var marker_cd9a38168771616c5ffcdd0a83f8c950 = L.marker(
#                 [-6.2491277499999995, 106.77778178322814],
#                 {
# }
#             ).addTo(marker_cluster_554eb163909c36c11ce9c63a8cc3b6c8);
#
#
#             var icon_f1c72cfc69dfac59f1c7f7c7ebebf649 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_cd9a38168771616c5ffcdd0a83f8c950.setIcon(icon_f1c72cfc69dfac59f1c7f7c7ebebf649);
#
#
#         var popup_ee3dcbdc5252eb723f693db84284dd

# %%
# Contoh penggunaan untuk menampilkan peta untuk tahun 2020-2024
map_result = create_map_by_year(2024)

# Menampilkan peta
map_result
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5af8b156ad81ee53646c65fe48fcb220 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5af8b156ad81ee53646c65fe48fcb220&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5af8b156ad81ee53646c65fe48fcb220 = L.map(
#                 &quot;map_5af8b156ad81ee53646c65fe48fcb220&quot;,
#                 {
#                     center: [-6.2, 106.85],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_070c7b1be9e2039025e5a9ca35858065 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_070c7b1be9e2039025e5a9ca35858065.addTo(map_5af8b156ad81ee53646c65fe48fcb220);
#
#
#             var marker_cluster_855a9bdefcd4cc6a3c3528e7f6d52c3d = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_52002ca99ff93d3ef765831d1f104c25 = L.marker(
#                 [-6.219081, 106.9524791],
#                 {
# }
#             ).addTo(marker_cluster_855a9bdefcd4cc6a3c3528e7f6d52c3d);
#
#
#             var icon_f658b44913f8c55f0a0d0c2022aee94a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_52002ca99ff93d3ef765831d1f104c25.setIcon(icon_f658b44913f8c55f0a0d0c2022aee94a);
#
#
#         var popup_21557ed2b1af56af7312756e908f7201 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6a01c93ae7166e2d9a0d559d9b591a0e = $(`&lt;div id=&quot;html_6a01c93ae7166e2d9a0d559d9b591a0e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Kecamatan:&lt;/b&gt; Cakung&lt;br&gt;&lt;b&gt;Status Banjir:&lt;/b&gt; Banjir&lt;br&gt;&lt;b&gt;Perbaikan Jalan:&lt;/b&gt; Tidak&lt;/div&gt;`)[0];
#                 popup_21557ed2b1af56af7312756e908f7201.setContent(html_6a01c93ae7166e2d9a0d559d9b591a0e);
#
#
#
#         marker_52002ca99ff93d3ef765831d1f104c25.bindPopup(popup_21557ed2b1af56af7312756e908f7201)
#         ;
#
#
#
#
#             var marker_a824459d0a2f9d0657b2b9fd8dbee9b8 = L.marker(
#                 [-6.181214499999999, 106.86854766095992],
#                 {
# }
#             ).addTo(marker_cluster_855a9bdefcd4cc6a3c3528e7f6d52c3d);
#
#
#             var icon_27aeb10ad921ff3df8bd2b3c5ec9b77a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_a824459d0a2f9d0657b2b9fd8dbee9b8.setIcon(icon_27aeb10ad921ff3df8bd2b3c5ec9b77a);
#
#
#         var popup_a1b0de62c8871bd4e43c2a6e403333e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63b904a65d79565597328363f8f14de6 = $(`&lt;div id=&quot;html_63b904a65d79565597328363f8f14de6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Kecamatan:&lt;/b&gt; Cempaka Putih&lt;br&gt;&lt;b&gt;Status Banjir:&lt;/b&gt; Tidak Banjir&lt;br&gt;&lt;b&gt;Perbaikan Jalan:&lt;/b&gt; Ada&lt;/div&gt;`)[0];
#                 popup_a1b0de62c8871bd4e43c2a6e403333e8.setContent(html_63b904a65d79565597328363f8f14de6);
#
#
#
#         marker_a824459d0a2f9d0657b2b9fd8dbee9b8.bindPopup(popup_a1b0de62c8871bd4e43c2a6e403333e8)
#         ;
#
#
#
#
#             var marker_488ea45bab9f1ccd47448dff393942ad = L.marker(
#                 [-6.1528985, 106.74471823726267],
#                 {
# }
#             ).addTo(marker_cluster_855a9bdefcd4cc6a3c3528e7f6d52c3d);
#
#
#             var icon_f6d6ddc02341cca7fc43c530c86e1f32 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_488ea45bab9f1ccd47448dff393942ad.setIcon(icon_f6d6ddc02341cca7fc43c530c86e1f32);
#
#
#         var popup_2c927c54d8553d613f41299ba08e87

# %%
# Asumsikan dataset diunggah dengan nama berikut
df = pd.read_excel('dataset_banjir_jkt.xlsx')

# Data preprocessing
df.dropna(inplace=True)  # Remove missing values
df['Target (Banjir/Tidak)'] = df['Target (Banjir/Tidak)'].astype(int)  # Ensure the target is an integer

# Filter unique kecamatan
kecamatan_relevant = df['Kecamatan'].unique()

# Feature encoding
X = pd.get_dummies(df[['Kecamatan', 'Range Tahun', 'Perbaikan Jalan (Ada/Tidak)']], drop_first=True)
y = df['Target (Banjir/Tidak)']

# Split data for training and testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# Standardize data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Train model
model = GaussianNB()
model.fit(X_train_scaled, y_train)

# Create prediction for 2025 with relevant kecamatan only
tahun_2025_data = pd.DataFrame({
    'Kecamatan': kecamatan_relevant,
    'Range Tahun': ['2025'] * len(kecamatan_relevant),
    'Perbaikan Jalan (Ada/Tidak)': [0] * len(kecamatan_relevant)  # Adjust as necessary
})

# One-hot encoding for prediction
X_2025 = pd.get_dummies(tahun_2025_data, columns=['Kecamatan', 'Range Tahun'], drop_first=True)
X_2025 = X_2025.reindex(columns=X.columns, fill_value=0)  # Align columns with training data

# Standardize 2025 data
X_2025_scaled = scaler.transform(X_2025)

# Predict for 2025
predictions_2025 = model.predict(X_2025_scaled)

# Map binary predictions to descriptive labels
prediction_labels = np.where(predictions_2025 == 1, 'banjir', 'tidak banjir')

# Combine kecamatan and predictions
result_2025 = pd.DataFrame({'Kecamatan': kecamatan_relevant, 'Prediksi (Banjir/Tidak)': prediction_labels})

# Function to drop duplicates while normalizing kecamatan names
def drop_duplicates_normalized(df, column_name):
    """
    Drops duplicates from a DataFrame by normalizing text values (case-insensitive, removing extra spaces).
    """
    # Normalize the column (case-insensitive and clean spaces)
    df[column_name] = df[column_name].str.lower().str.strip().str.replace(r'\s+', ' ', regex=True)

    # Drop duplicates
    df_unique = df.drop_duplicates(subset=[column_name]).reset_index(drop=True)

    return df_unique

# Apply the function to remove duplicates from the predictions
result_2025_unique = drop_duplicates_normalized(result_2025, 'Kecamatan')

# Inisialisasi geolocator untuk mendapatkan koordinat
geolocator = Nominatim(user_agent="prediksi_banjir_2025", timeout=10)
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)

# Fungsi untuk mendapatkan koordinat setiap kecamatan
def get_coordinates(kecamatan):
    try:
        location = geocode(f"{kecamatan}, Jakarta, Indonesia")
        if location:
            return (location.latitude, location.longitude)
        else:
            return (None, None)
    except Exception as e:
        print(f"Error getting coordinates for {kecamatan}: {e}")
        return (None, None)

# Dapatkan koordinat untuk setiap kecamatan
coordinates = result_2025_unique['Kecamatan'].apply(get_coordinates)
result_2025_unique['Latitude'] = coordinates.apply(lambda x: x[0])
result_2025_unique['Longitude'] = coordinates.apply(lambda x: x[1])

# Filter kecamatan dengan koordinat valid
result_valid = result_2025_unique.dropna(subset=['Latitude', 'Longitude'])

# Buat peta interaktif
m = folium.Map(location=[-6.2, 106.8], zoom_start=11)  # Lokasi pusat Jakarta

# Tambahkan MarkerCluster
marker_cluster = MarkerCluster().add_to(m)

# Tambahkan marker untuk setiap kecamatan
for _, row in result_valid.iterrows():
    color = 'red' if row['Prediksi (Banjir/Tidak)'] == 'banjir' else 'green'
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=folium.Popup(f"<b>Kecamatan:</b> {row['Kecamatan']}<br><b>Prediksi:</b> {row['Prediksi (Banjir/Tidak)']}", max_width=300),
        icon=folium.Icon(color=color)
    ).add_to(marker_cluster)

# Simpan peta
m.save("prediksi_banjir_2025.html")

# Tampilkan peta
print("Peta berhasil dibuat dan disimpan sebagai 'prediksi_banjir_2025.html'")
m
# Out:
# Peta berhasil dibuat dan disimpan sebagai 'prediksi_banjir_2025.html'
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dfa7c7eccb5bf2991d37de7dba2a9d89 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dfa7c7eccb5bf2991d37de7dba2a9d89&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dfa7c7eccb5bf2991d37de7dba2a9d89 = L.map(
#                 &quot;map_dfa7c7eccb5bf2991d37de7dba2a9d89&quot;,
#                 {
#                     center: [-6.2, 106.8],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7c904b0cf0b088cb11d0ee7e53f97b45 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7c904b0cf0b088cb11d0ee7e53f97b45.addTo(map_dfa7c7eccb5bf2991d37de7dba2a9d89);
#
#
#             var marker_cluster_bd94343ac7802e7bc41977193f78a49b = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_4af03678c4c8e54d8e2f5b9bd1830fa0 = L.marker(
#                 [-6.12885785, 106.87079323031739],
#                 {
# }
#             ).addTo(marker_cluster_bd94343ac7802e7bc41977193f78a49b);
#
#
#             var icon_77efaaed10fa0e492c3bc7d348bb7a41 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_4af03678c4c8e54d8e2f5b9bd1830fa0.setIcon(icon_77efaaed10fa0e492c3bc7d348bb7a41);
#
#
#         var popup_cc5d37384de27a46b79410465a924893 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_012413b8ea4fb3001e3571e26a2f5a33 = $(`&lt;div id=&quot;html_012413b8ea4fb3001e3571e26a2f5a33&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Kecamatan:&lt;/b&gt; tanjung priok&lt;br&gt;&lt;b&gt;Prediksi:&lt;/b&gt; banjir&lt;/div&gt;`)[0];
#                 popup_cc5d37384de27a46b79410465a924893.setContent(html_012413b8ea4fb3001e3571e26a2f5a33);
#
#
#
#         marker_4af03678c4c8e54d8e2f5b9bd1830fa0.bindPopup(popup_cc5d37384de27a46b79410465a924893)
#         ;
#
#
#
#
#             var marker_8c82b758afad53a462085a2c5b197b39 = L.marker(
#                 [-6.219081, 106.9524791],
#                 {
# }
#             ).addTo(marker_cluster_bd94343ac7802e7bc41977193f78a49b);
#
#
#             var icon_ccf82944c433c06ed2f299ef55f3d0e8 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_8c82b758afad53a462085a2c5b197b39.setIcon(icon_ccf82944c433c06ed2f299ef55f3d0e8);
#
#
#         var popup_425b6d160cb85d76bdf2de4057635824 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_c565db2f2727362bb11e847d08b5e13b = $(`&lt;div id=&quot;html_c565db2f2727362bb11e847d08b5e13b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Kecamatan:&lt;/b&gt; cakung&lt;br&gt;&lt;b&gt;Prediksi:&lt;/b&gt; banjir&lt;/div&gt;`)[0];
#                 popup_425b6d160cb85d76bdf2de4057635824.setContent(html_c565db2f2727362bb11e847d08b5e13b);
#
#
#
#         marker_8c82b758afad53a462085a2c5b197b39.bindPopup(popup_425b6d160cb85d76bdf2de4057635824)
#         ;
#
#
#
#
#             var marker_da0c94e68fd8f97c16f3145c8bfea199 = L.marker(
#                 [-6.13700575, 106.70159379305983],
#                 {
# }
#             ).addTo(marker_cluster_bd94343ac7802e7bc41977193f78a49b);
#
#
#             var icon_c3116436010d2b9d3232fb60cde02630 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_da0c94e68fd8f97c16f3145c8bfea199.setIcon(icon_c3116436010d2b9d3232fb60cde02630);
#
#
#         var popup_13467ce579c6bba9fe8949ef29112844 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_bd4bcd61926e441ee40b84a4923fc0ba = $(`&lt;div id=&quot;

# %%
# Buat Pie Chart
plt.figure(figsize=(8, 6))
sns.set(style="whitegrid")
result_2025_unique['Prediksi (Banjir/Tidak)'].value_counts().plot.pie(
    autopct='%1.1f%%',
    colors=['red', 'green'],
    labels=['Banjir', 'Tidak Banjir'],
    startangle=90,
    wedgeprops=dict(edgecolor='black')
)
plt.title("Distribusi Prediksi Banjir Tahun 2025")
plt.ylabel('')  # Hilangkan label y
plt.show()

# %%
result_2025_unique
# Out:
#             Kecamatan Prediksi (Banjir/Tidak)  Latitude   Longitude
# 0       tanjung priok                  banjir -6.128858  106.870793
# 1              cakung                  banjir -6.219081  106.952479
# 2           kalideres                  banjir -6.137006  106.701594
# 3           kemayoran                  banjir -6.161703  106.841401
# 4       cempaka putih                  banjir -6.181214  106.868548
# 5      kebayoran lama            tidak banjir -6.249128  106.777782
# 6           jagakarsa                  banjir -6.330101  106.822237
# 7   grogol petamburan                  banjir -6.164188  106.788317
# 8          cengkareng                  banjir -6.152899  106.744718
# 9          pasar rebo                  banjir -6.324973  106.853376
# 10            tambora                  banjir -6.146614  106.801046
# 11            ciracas                  banjir -6.329635  106.876604
# 12           cilandak                  banjir -6.289798  106.796926
# 13        pulo gadung                  banjir -6.191109  106.890605
# 14       pasar minggu                  banjir -6.283332  106.844856
# 15          cilincing            tidak banjir -6.129015  106.944454
# 16              senen                  banjir -6.174423  106.844574
# 17         pademangan                  banjir -6.129052  106.828972
# 18           cipayung                  banjir -6.329399  106.903739
# 19        kebon jeruk                  banjir -6.192572  106.769725
# 20             gambir                  banjir -6.176655  106.830647
# 21         jatinegara            tidak banjir -6.214925  106.870339
# 22           matraman                  banjir -6.212567  106.859753
# 23     kebayoran baru                  banjir -6.243164  106.799850
# 24        duren sawit                  banjir -6.234138  106.919247
# 25        kramat jati                  banjir -6.274912  106.862491
# 26            menteng            tidak banjir -6.195026  106.832224
# 27         johar baru                  banjir -6.183125  106.855332
# 28           palmerah            tidak banjir -6.207137  106.797591
# 29          kembangan                  banjir -6.191356  106.740587
# 30       pesanggrahan                  banjir -6.255458  106.763112
# 31   mampang prapatan                  banjir -6.250878  106.823021
# 32        sawah besar                  banjir -6.160667  106.827655
# 33        penjaringan                  banjir -6.117265  106.767433
# 34              tebet            tidak banjir -6.226398  106.858439
# 35         taman sari                  banjir -6.146142  106.818499
# 36            makasar                  banjir -6.269587  106.888697
# 37      kelapa gading                  banjir -6.159938  106.902483
# 38          setiabudi                  banjir -6.221707  106.826308
# 39           pancoran                  banjir -6.258085  106.842733
# 40               koja                  banjir -6.120750  106.907367
# 41        tanah abang                  banjir -6.185713  106.810894
